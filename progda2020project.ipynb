# %% [markdown]
# # Programming for Data Analysis

# %% [markdown]
# <cr>

# %% [markdown]
# ## Project 2020

# %% [markdown]
# ## Due: 03 January 2021

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# For this project you must create a data set by simulating a real-world phenomenon of
# your choosing. You may pick any phenomenon you wish – you might pick one that is
# of interest to you in your personal or professional life. Then, rather than collect data
# related to the phenomenon, you should model and synthesise such data using Python.
# We suggest you use the numpy.random package for this purpose.
# Specifically, in this project you should:
# • Choose a real-world phenomenon that can be measured and for which you could
# collect at least one-hundred data points across at least four different variables.
# • Investigate the types of variables involved, their likely distributions, and their
# relationships with each other.
# • Synthesise/simulate a data set as closely matching their properties as possible.
# • Detail your research and implement the simulation in a Jupyter notebook – the
# data set itself can simply be displayed in an output cell within the notebook.
# Note that this project is about simulation – you must synthesise a data set. Some
# students may already have some real-world data sets in their own files. It is okay to
# base your synthesised data set on these should you wish (please reference it if you do),
# but the main task in this project is to create a synthesised data set.

# %% [markdown]
# ## Introduction

# %% [markdown]
#  These is my solution in relation to the above problem statement. The author is Jean Bonsenge. Email: g00387887@gmit.ie

# %% [markdown]
# ## References
#
# [1]EU Open Data Portal (2020) “COVID-19 Coronavirus data”.
#
# https://data.europa.eu/euodp/en/data/dataset/covid-19-coronavirus-data/resource/260bbbde-2316-40eb-aec3-7cd7bfc2f590(Accessed 10/12/2020)
#
# [2] Geeksforgeeks(2020)"Plotting Histogram in Python using Matplotlibhttps"://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/(Accessed 10/12/2020)
#
# [3] Geeksforgeeks(2020) "Python | Pandas Extracting rows using .loc[]: https://www.geeksforgeeks.org/python-pandas-extracting-rows-using-loc/(Accessed 10/12/2020)
#
# [4] Geeksforgeeks(2020) "Python | Extracting rows using Pandas .iloc[]: https://www.geeksforgeeks.org/python-extracting-rows-using-pandas-iloc/(Accessed 10/12/2020)
#
# [5] McKinney W. (2013) “Python for Data Analysis"(Sebastopol: O’Reilly Media, Inc)
#
#
# [6]Numpy(2020)"Random Generator"https://numpy.org/doc/stable/reference/random/generator.html#distributions(Accessed 15/12/2020)
#
# [7] Numpy (2020) "numpy.random.Generator.gumbel"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.gumbel.html#numpy.random.Generator.gumbel(Accessed 20/12/2020)
#
# [8] Numpy(2020) "numpy.random.Generator.hypergeometric"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.hypergeometric.html#numpy.random.Generator.hypergeometric(Accessed 02/12/2020)
#
# [9] Numpy (2020) "numpy.random.Generator.logistic"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.logistic.html#numpy.random.Generator.logistic
# [10] Numpy (2020) "numpy.random.Generator.noncentral_chisquare"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_chisquare.html#numpy.random.Generator.noncentral_chisquare(Accessed 10/12/2020)
#
# [11] Numpy(2020) "numpy.random.Generator.noncentral_f"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_f.html#numpy.random.Generator.noncentral_f(Accessed 05/12/2020)
#
# [12] Numpy(2020)"numpy.random.Generator.logistic"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.logistic.html#numpy.random.Generator.logistic(Accessed 30/11/2020)
# [13] Numpy(2020) "numpy.random.Generator.noncentral_chisquare"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_chisquare.html#numpy.random.Generator.noncentral_chisquare(Accessed 10/12/2020)

# %% [markdown]
# ## Development

# %% [markdown]
# ### A real-world phenomenon: Coronavirus disease 2019 (COVID-19)

# %%
# Magic command in Ipython displaying the output.  
# %matplotlib inline

# Numercial arrays and fitting lines
import numpy as np
# Plots.
import matplotlib.pyplot as plt
# Data visualisation
import seaborn as sns
# Nicer plot style.
plt.style.use('ggplot')
# Bigger plots.
plt.rcParams['figure.figsize'] = 14, 10

#Import pandas as pd for data analysis and manipulation.
import pandas as pd
# Pandas DataFrame() function to read the csv file.
df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")

# %% [markdown]
# ### About the dataset
# This dataset is about Covid-19 worldwide issued by the EU Open Data Portal[1].
#
# A csv dataset that contains 57640 rows and 12 columns(variables). See the output below.

# %%
# Call DataFrame()function.
df
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      24/11/2020   24     11  2020    246      17             Afghanistan
# 1      23/11/2020   23     11  2020    252       8             Afghanistan
# 2      22/11/2020   22     11  2020    154      12             Afghanistan
# 3      21/11/2020   21     11  2020    232      25             Afghanistan
# 4      20/11/2020   20     11  2020    282       5             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 57635  25/03/2020   25      3  2020      0       0                Zimbabwe
# 57636  24/03/2020   24      3  2020      0       1                Zimbabwe
# 57637  23/03/2020   23      3  2020      0       0                Zimbabwe
# 57638  22/03/2020   22      3  2020      1       0                Zimbabwe
# 57639  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %% [markdown]
# ### Dataset Summary

# %%
# Output the five first rows and all twelve variables.
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  24/11/2020   24     11  2020    246      17             Afghanistan    AF
# 1  23/11/2020   23     11  2020    252       8             Afghanistan    AF
# 2  22/11/2020   22     11  2020    154      12             Afghanistan    AF
# 3  21/11/2020   21     11  2020    232      25             Afghanistan    AF
# 4  20/11/2020   20     11  2020    282       5             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           6.713675
# 1                                           6.655844
# ...

# %%
# Output the last five rows and twelve variables.
df.tail()
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 57635  25/03/2020   25      3  2020      0       0                Zimbabwe
# 57636  24/03/2020   24      3  2020      0       1                Zimbabwe
# 57637  23/03/2020   23      3  2020      0       0                Zimbabwe
# 57638  22/03/2020   22      3  2020      1       0                Zimbabwe
# 57639  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 57635    ZW                  ZWE   14645473.0       Africa
# 57636    ZW                  ZWE   14645473.0       Africa
# 57637    ZW                  ZWE   14645473.0       Africa
# 57638    ZW                  ZWE   14645473.0       Africa
# 57639    ZW                  ZWE   14645473.0       Africa
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 57635                                                NaN
# ...

# %%
# Output a summary of the dataset: count, mean, std, min, 25%, average(50%), 75% and max.
df.describe()
# Out:
#                 day         month          year          cases        deaths  \
# count  57640.000000  57640.000000  57640.000000   57640.000000  57640.000000
# mean      15.786103      6.724774   2019.998838    1028.929441     24.248300
# std        8.745097      2.767141      0.034074    5836.617972    125.652523
# min        1.000000      1.000000   2019.000000   -8261.000000  -1918.000000
# 25%        8.000000      5.000000   2020.000000       0.000000      0.000000
# 50%       16.000000      7.000000   2020.000000      14.000000      0.000000
# 75%       23.000000      9.000000   2020.000000     237.000000      4.000000
# max       31.000000     12.000000   2020.000000  196117.000000   4928.000000
#
#         popData2019  \
# count  5.753700e+04
# mean   4.134196e+07
# std    1.540102e+08
# min    8.150000e+02
# 25%    1.324820e+06
# 50%    7.813207e+06
# 75%    2.860872e+07
# max    1.433784e+09
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# ...

# %% [markdown]
# ### Selection of four variables of interest

# %% [markdown]
# ##### .loc () function

# %%
# With .loc function select four variables of interest:cases, deaths, popData2019 and cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
# Select 100 rows or points from 0-100.
df.loc[0:100,["cases", "deaths","popData2019", "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"]]
# Out:
#      cases  deaths  popData2019  \
# 0      246      17   38041757.0
# 1      252       8   38041757.0
# 2      154      12   38041757.0
# 3      232      25   38041757.0
# 4      282       5   38041757.0
# ..     ...     ...          ...
# 96     160       8   38041757.0
# 97       0       0   38041757.0
# 98       3       0   38041757.0
# 99      45       5   38041757.0
# 100    120       7   38041757.0
#
#      Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                             6.713675
# 1                                             6.655844
# 2                                             6.203709
# 3                                             6.130106
# 4                                             5.672714
# ..                                                 ...
# 96                                            2.268560
# 97                                            2.024092
# 98                                            2.239644
# ...

# %% [markdown]
# #### .iloc () function
#
# ### cases

# %%
# Display the fourth variable and its values using .iloc() function.
df.iloc[0:100, 4]
# Out:
# 0     246
# 1     252
# 2     154
# 3     232
# 4     282
#      ...
# 95     97
# 96    160
# 97      0
# 98      3
# 99     45
# Name: cases, Length: 100, dtype: int64

# %% [markdown]
# ### deaths

# %%
# Display the fifth variable and its values using .iloc() function.
df.iloc[0:100, 5]
# Out:
# 0     17
# 1      8
# 2     12
# 3     25
# 4      5
#       ..
# 95     2
# 96     8
# 97     0
# 98     0
# 99     5
# Name: deaths, Length: 100, dtype: int64

# %% [markdown]
# ### popData

# %%
# Display the ninth variable and its values using .iloc() function.
df.iloc[0:100, 9]
# Out:
# 0     38041757.0
# 1     38041757.0
# 2     38041757.0
# 3     38041757.0
# 4     38041757.0
#          ...
# 95    38041757.0
# 96    38041757.0
# 97    38041757.0
# 98    38041757.0
# 99    38041757.0
# Name: popData2019, Length: 100, dtype: float64

# %% [markdown]
# ### Cumulative_number_for_14_days_of_COVID-19_cases_per_100000

# %%
# Display the eleventh variable and its values using .iloc() function.
df.iloc[0:100, 11]
# Out:
# 0     6.713675
# 1     6.655844
# 2     6.203709
# 3     6.130106
# 4     5.672714
#         ...
# 95    2.415766
# 96    2.268560
# 97    2.024092
# 98    2.239644
# 99    2.329020
# Name: Cumulative_number_for_14_days_of_COVID-19_cases_per_100000, Length: 100, dtype: float64

# %% [markdown]
# ### Investigating variables

# %% [markdown]
# ### Types of variables

# %% [markdown]
# #### Cases

# %%
# Using Matplotlib.pyplot hist() function for the .loc () function to display an histogram for the variable:
# "cases".
# Get histogram.
plt.hist(df.loc[0:100,"cases"])
# Histogram title and labels.
plt.title("A histogram on Covid-19 cases using .loc() function")
plt.xlabel("cases")
plt.ylabel("frequency")
# Display histogram.
plt.show()

# %% [markdown]
# A bin between 0-50 scores above 40 frequency suggesting a huge distribution of cases at that level.

# %%
# Using Matplotlib.pyplot hist() function for the .iloc () function to display an histogram for the variable:
# "cases".
# Get histogram.
plt.hist(df.iloc[0:100,4])
# Histogram title and labels.
plt.title("A histogram on Covid-19 cases using .iloc() function")
plt.xlabel("cases")
plt.ylabel("frequency")
# Display histogram.
plt.show()

# %% [markdown]
# .loc() function and .iloc() function produce the same outcome on Covid-19 cases as on plots above: a bin between 0-50 scores above 40 frequency suggesting a huge distribution of cases at that level.

# %% [markdown]
# #### Deaths

# %%
# Using Matplotlib.pyplot hist() function for the .loc () function to display an histogram for the variable:
# "deaths".

# Get histogram.
plt.hist(df.loc[0:100,"deaths"])
# Histogram title and labels.
plt.title("A histogram on Covid-19 deaths using .loc() function")
plt.xlabel("deaths")
plt.ylabel("frequency")
# Display histogram.
plt.show()

# %% [markdown]
# A bin between 0-5 scores above 50 frequency suggesting a huge distribution of deaths at that level.

# %%
# Using Matplotlib.pyplot hist() function for the .iloc () function to display an histogram for the variable:
# "deaths".
# Get histogram.
plt.hist(df.iloc[0:100,5])
# Histogram title and labels.
plt.title("A histogram on Covid-19 deaths using .iloc() function")
plt.xlabel("deaths")
plt.ylabel("frequency")
# Show histogram.
plt.show()

# %% [markdown]
# .loc() function and .iloc() function produce the same outcome on Covid-19 deaths as on plots above: a bin between 0-5 scores above 50 frequency suggesting a huge distribution of deaths at that level.

# %% [markdown]
# #### PopData2019

# %%
# Using Matplotlib.pyplot hist() function for the .loc () function to display an histogram for the variable:
# "popData2019".
# Get histogram.
plt.hist(df.loc[0:100,"popData2019"])
# Histogram title and labels.
plt.title("A histogram on Covid-19 popData2019 using .loc() function")
plt.xlabel("popData2019")
plt.ylabel("frequency")
# Display output.
plt.show()

# %% [markdown]
# A unique bin between 7.0-7.2 scores above 100 frequency suggesting a huge distribution of popData2019 at that level.

# %%
# Using Matplotlib.pyplot hist() function for the .iloc () function to display an histogram for the variable:
# "popData2019".
# Get histogram.
plt.hist(df.iloc[0:100,9])
# Histogram title and labels.
plt.title("A histogram on Covid-19 popData2019 using .iloc() function")
plt.xlabel("popData2019")
plt.ylabel("frequency")
# Display output.
plt.show()

# %% [markdown]
# .loc() function and .iloc() function produce the same outcome on Covid-19 popData2019 as on plots above:A unique bin between 7.0-7.2 scores above 100 frequency suggesting a huge distribution of popData2019 at that level.

# %% [markdown]
# #### Cumulative_number_for_14_days_of_COVID-19_cases_per_100000

# %%
# Using Matplotlib.pyplot hist() function for the .loc () function to display an histogram for the variable:
# "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000".

# Get histogram
plt.hist(df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"])
# Histogram title and labels.
plt.title("A histogram on Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 using .loc() function")
plt.xlabel("Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
plt.ylabel("frequency")
# Display output.
plt.show()

# %% [markdown]
# A bin between 1 to 2 scores above 25 frequency suggesting a huge distribution of Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 at that level.

# %%
# Using Matplotlib.pyplot hist() function for the .iloc () function to display an histogram for the variable:
# "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000".

# Get histogram.
plt.hist(df.iloc[0:100,11])
# Histogram title and labels.
plt.title("A histogram on Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 using .iloc() function")
plt.xlabel("Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
plt.ylabel("frequency")
# Display output.
plt.show()

# %% [markdown]
# loc() function and .iloc() function produce the same outcome on Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 as on the above plots: a bin between 1 to 2 scores above 25 frequency suggesting a huge distribution of Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 at that level.

# %% [markdown]
# ### Distributions based on simulation

# %% [markdown]
# Numpy(2020)"Random Generator"https://numpy.org/doc/stable/reference/random/generator.html#distributions

# %% [markdown]
# ### numpy.random.Generator.gumbel

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.gumbel.html#numpy.random.Generator.gumbel
# numpy.random.Generator.gumbel
#
# Draw samples from the distribution:

# %%
# Draw samples from the distribution:
rng = np.random.default_rng()
mu, beta = 0, 0.1 # location and scale
# Generate an array for cases.
cases = rng.gumbel(mu, beta, 100)

# %%
# Execute.
cases
# Out:
# array([ 0.0403532 ,  0.23028401, -0.01509758, -0.04971043,  0.07064422,
#         0.0701262 ,  0.13476676,  0.0374602 , -0.0893413 ,  0.17298126,
#         0.45349981,  0.60102426,  0.00183477,  0.17749325, -0.09172596,
#         0.23034027,  0.04031723, -0.03544976,  0.03259316,  0.14195574,
#         0.14054008,  0.00982066,  0.14785109, -0.00716945, -0.03139702,
#         0.14469719, -0.11846276, -0.07508695, -0.01276081, -0.08471788,
#         0.35021454,  0.07440431, -0.1229212 , -0.0358806 , -0.01260961,
#        -0.03691613,  0.08270781,  0.12480676, -0.08656018,  0.06606788,
#         0.2571461 , -0.00479189,  0.63008937,  0.24866166,  0.08195705,
#         0.09386183,  0.08464423,  0.20446154,  0.02280363,  0.09841661,
#         0.17179272,  0.13478879, -0.05224446,  0.15629281,  0.01800059,
#        -0.15153122,  0.00634334,  0.40660339, -0.0210225 ,  0.1366076 ,
#        -0.02062532,  0.21276257, -0.04779427, -0.01754222,  0.0306706 ,
# ...

# %%
# Check lenght.
len(cases)
# Out:
# 100

# %%
#Display the histogram of the samples, along with the probability density function:
import matplotlib.pyplot as plt
# Histogram features.
count, bins, ignored = plt.hist(cases, 30, density=True)
# Get histogram.
plt.plot(bins, (1/beta)*np.exp(-(bins - mu)/beta) * np.exp( -np.exp( -(bins - mu) /beta) ), linewidth=2, color='b')
# Histogram title and labels.
plt.title("A histogram on cases using probability density () function")
plt.xlabel("cases, on a Gumbel distribution")
plt.ylabel("frequency")
# Show output.
plt.show()

# %% [markdown]
# A bell-curve plot is displayed on the above histogram in which one bin situated between -0.1 to 0.0 bins reaches at almost 7 frequency at y(axis). This is reproduced on the outputs of other variables while using the distributions function gumble () as below.

# %%
# Generate an array for the variable deaths.
rng = np.random.default_rng()
mu, beta = 0, 0.1 # location and scale
deaths = rng.gumbel(mu, beta, 100)

# %%
# Execute
deaths
# Out:
# array([ 0.26932878,  0.03932658,  0.13161529, -0.03487115, -0.12194595,
#         0.40121506, -0.0065396 ,  0.01886015,  0.29070329,  0.16460985,
#         0.1176011 , -0.15159724,  0.11892138,  0.00547729, -0.03782454,
#         0.20712796,  0.07713727,  0.05268077,  0.00193025,  0.06805564,
#        -0.05624453,  0.12815828,  0.24081788,  0.23832023,  0.02444572,
#         0.124899  , -0.02718548, -0.04829634, -0.0673736 ,  0.28018653,
#         0.06356617,  0.04439977, -0.02286398, -0.03371774,  0.07189097,
#         0.02152989, -0.0340039 ,  0.19641946, -0.05828532,  0.10734869,
#         0.25505433, -0.10550883, -0.03232944,  0.12566825,  0.16890864,
#         0.10456591,  0.04732213,  0.01579835, -0.11965431,  0.10653412,
#        -0.06334065,  0.05769602, -0.0186239 ,  0.11312479, -0.03881664,
#        -0.08237646, -0.06012218,  0.05344164, -0.08008517, -0.03255519,
#        -0.02450338, -0.04229901, -0.08159942, -0.03633569, -0.06019507,
# ...

# %%
# Check length.
len(deaths)
# Out:
# 100

# %%
# Import Matplotlib.pyplot.
import matplotlib.pyplot as plt
# Set histogram features for the variable deaths.
count, bins, ignored = plt.hist(deaths, 30, density=True)
# Get a plot.
plt.plot(bins, (1/beta)*np.exp(-(bins - mu)/beta) * np.exp( -np.exp( -(bins - mu) /beta) ), linewidth=2, color='b')
# Histogram and plot title and labels.
plt.title("A histogram on deaths using probability density () function")
plt.xlabel("deaths, on a Gumbel distribution")
plt.ylabel("frequency")
# Displat output.
plt.show()

# %%
# Generate an array for the variable popData2019.
rng = np.random.default_rng()
mu, beta = 0, 0.1 # location and scale
popData2019 = rng.gumbel(mu, beta, 100)

# %%
# Execute.
popData2019
# Out:
# array([-0.02617843, -0.107002  , -0.14138911,  0.03035978,  0.10951988,
#        -0.100029  , -0.09945506,  0.13933989,  0.01175394, -0.08771016,
#        -0.09342084,  0.09965377, -0.02431253,  0.03874237,  0.27875296,
#         0.02952261,  0.12736968,  0.13629768, -0.0255838 , -0.00440643,
#        -0.06775493,  0.01412418,  0.06505967,  0.31250684,  0.13905621,
#         0.09903347,  0.14242502,  0.11889337,  0.11137759,  0.15502234,
#         0.0567717 ,  0.04345334, -0.02638745, -0.06962248, -0.00138599,
#         0.09830754, -0.03198417, -0.0678693 ,  0.15578202, -0.03032046,
#        -0.03053953, -0.01074279,  0.12168015,  0.08057424,  0.05891183,
#         0.16978503,  0.09394085,  0.05005104,  0.06745895,  0.04760051,
#        -0.03493014,  0.2457489 , -0.00540516,  0.04093079,  0.04033387,
#         0.1300214 ,  0.25551891, -0.12157855,  0.10919252,  0.23424559,
#        -0.02764648,  0.12929445, -0.01132573, -0.01595667,  0.07052809,
# ...

# %%
# Check length.
len(popData2019)
# Out:
# 100

# %%
# Import Matplotlib.pyplot
import matplotlib.pyplot as plt

# Set histogram features for the variable popData2019.
count, bins, ignored = plt.hist(popData2019, 30, density=True)
# Get a plot.
plt.plot(bins, (1/beta)*np.exp(-(bins - mu)/beta) * np.exp( -np.exp( -(bins - mu) /beta) ), linewidth=2, color='b')

# Histogram and plot title and labels.
plt.title("A histogram on popData2019 using probability density () function")
plt.xlabel("popData2019, on a Gumbel distribution")
plt.ylabel("frequency")

# Display output.
plt.show()

# %% [markdown]
# ### numpy.random.Generator.hypergeometric

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.hypergeometric.html#numpy.random.Generator.hypergeometric
#
# hypergeometric(ngood, nbad, nsample[, size])

# %%
"""hypergeometric(ngood, nbad, nsample[, size]).This function is used to draw sample from a Hypergeometric distribution.""" 

# Import hist () function from Matplotlib.pyplot.

from matplotlib.pyplot import hist
# Generate an array for the variable cases.
rng = np.random.default_rng()
# Set parameters.
ngood, nbad, nsamp = 100, 2, 10
# Define variable cases.
cases = rng.hypergeometric(ngood, nbad, nsamp, 100)

# %%
# Execute.
cases
# Out:
# array([10,  9, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,  9, 10, 10, 10, 10,
#        10, 10,  9, 10, 10, 10, 10,  9, 10, 10, 10,  8, 10, 10, 10, 10, 10,
#        10,  9, 10,  9,  9, 10, 10, 10, 10,  9, 10, 10, 10, 10, 10, 10, 10,
#        10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,  9, 10,
#        10, 10, 10, 10, 10, 10, 10, 10, 10, 10,  9,  8, 10, 10, 10,  9, 10,
#        10, 10, 10,  9,  9, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#       dtype=int64)

# %%
# Plot labels
plt.title("A histogram on cases using Hypergeometric distribution () function")
plt.xlabel("cases, on a Hypergeometric distribution")
plt.ylabel("frequency")

# Plot hist() function.
hist(cases)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0., 13.,  0.,  0.,  0., 85.]),
#  array([ 8. ,  8.2,  8.4,  8.6,  8.8,  9. ,  9.2,  9.4,  9.6,  9.8, 10. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# A hypergeometric distribution is displayed on simulated cases with a rise of pick at 10.00 (x-axis)

# %% [markdown]
# ### numpy.random.Generator.logistic
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.logistic.html#numpy.random.Generator.logistic

# %% [markdown]
# Generator.logistic(loc=0.0, scale=1.0, size=None)

# %%
"""logistic([loc, scale, size]). Draw samples from a logistic distribution. 
Samples are drawn from a logistic distribution with specified parameters, loc(location or mean, also median), and scale (>0)"""

# Import Numpy and Matoplotlib.pyplot.
import numpy as np  
import matplotlib.pyplot as plt  
# Set parameters.
loc, scale = 10, 1  
# Set variable deaths.
deaths = np.random.logistic(loc, scale, 100)

# %%
# Generate an array.
deaths = np.random.logistic(loc, scale, 100)

# %%
# Execute.
deaths
# Out:
# array([14.38762443, 11.25148844,  8.24077941, 11.22347414,  9.9149651 ,
#        14.40143101,  9.39946138,  8.51122417,  9.80875322,  9.80624288,
#        11.64350926, 12.76553221, 10.41607759, 10.69622538, 11.72015994,
#        10.7162676 ,  8.9948447 , 10.79130142,  7.75846669,  9.93000653,
#         8.53790008,  8.50214923, 11.71751026,  7.84940813, 14.74715246,
#         9.65928219, 13.61890673, 10.9297251 , 12.74032529, 12.2087491 ,
#         7.50563747, 11.36657166,  7.31496743,  9.4026047 , 15.12361764,
#        10.64368499, 11.42343118,  7.50532448, 11.30900177, 13.70951537,
#        11.70935241, 10.39594546,  9.69211509,  8.4529478 , 11.83437577,
#         7.48469745, 14.37881748,  9.95986548,  9.76841404, 10.24076327,
#        10.65685624,  9.94232359,  9.6708701 , 10.61787306,  9.49349419,
#         9.46292128, 11.57960164,  9.41313786,  9.86949868,  9.66129359,
#         8.04914132,  9.80524318,  8.88913548,  9.87532016, 11.28014163,
# ...

# %%
# Check lenght.
len(deaths)
# Out:
# 100

# %%
# Import Numpy and Matplolib.pyplot
import numpy as np  
import matplotlib.pyplot as plt  

#Set location and scale of the varaible deaths
loc, scale = 10, 1  
# Variable death and values
deaths = np.random.logistic(loc, scale, 100)  
# Set histogram features
count, bins, ignored = plt.hist(deaths, bins=50)  

# Plot labels
plt.title("A histogram on deaths using a Logistic distribution () function")
plt.xlabel("deaths, on a Logistic distribution")
plt.ylabel("frequency")

# Show plot
plt.show()

# %% [markdown]
# A Logistic distribution is displayed on simulated deaths with a rise situated between 8 and 10(x-axis) and reaching 8 (y-axis).

# %%
# Plot against distribution.

# Set histogram features.
count, bins, ignored = plt.hist(deaths, bins=50)  

# Define logist function to plot against distribution
def logist(deaths, loc, scale):
    return np.exp((loc-deaths)/scale)/(scale*(1+np.exp((loc-deaths)/scale))**2)
lgst_val = logist(bins, loc, scale)
plt.plot(bins, lgst_val * count.max() / lgst_val.max())

# Plot labels.
plt.title("A histogram on deaths plotting against Logistic distribution")
plt.xlabel("deaths, on a Logistic distribution")
plt.ylabel("frequency")

# Plot against distribution.
plt.show()

# %% [markdown]
# A histogram on deaths plotting against Logistic distribution and curved at 10 (x-axis).

# %% [markdown]
# ### numpy.random.Generator.noncentral_chisquare
# Draw samples from a noncentral chi-square distribution.

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_chisquare.html#numpy.random.Generator.noncentral_chisquare

# %% [markdown]
# Generator.noncentral_chisquare(df, nonc, size=None)

# %%
# Draw values from the distribution and plot the histogram.

# Import Matplotlib.pyplot for plotting
import matplotlib.pyplot as plt

# Generate an array of data.
rng = np.random.default_rng()
# Set variable popData2019.
popData2019 = plt.hist(rng.noncentral_chisquare(3, 20, 100000),bins=200, density=True)

# Plot labels
plt.title("A histogram on popData2019 using a Noncentral_chisquare distribution () function")
plt.xlabel("popData2019, on a Noncentral_chisquare distribution")
plt.ylabel("frequency")

# Show plot
plt.show()

# %% [markdown]
# A histogram on popData2019 using a Noncentral_chisquare distribution () function is displayed with significant rise at 20 (x-axis)

# %% [markdown]
# # numpy.random.Generator.noncentral_f

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_f.html#numpy.random.Generator.noncentral_f

# %% [markdown]
# Generator.noncentral_f(dfnum, dfden, nonc, size=None).
#
# Draw samples from the noncentral F distribution.

# %%
#https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_f.html#numpy.random.Generator.noncentral_f 

# Import Matplotlib.pyplot.
import matplotlib.pyplot as plt

# To generate an array.
rng = np.random.default_rng()
dfnum = 3 # between group deg of freedom
dfden = 20 # within groups degrees of freedom
nonc = 3.0
# Set Variable popData2019.
popData2019 = rng.noncentral_f(dfnum, dfden, nonc, 1000000)
# Set histogram parameters.
NF = np.histogram(popData2019, bins=50, density=True)
c_vals = rng.f(dfnum, dfden, 1000000)
F = np.histogram(c_vals, bins=50, density=True)
# Plot title and labels
plt.title("A histogram on popData2019 using a Noncentral_f distribution () function")
plt.xlabel("popData2019, on a Noncentral_f distribution")
plt.ylabel("frequency")
# Plots.
plt.plot(F[1][1:], F[0])
plt.plot(NF[1][1:], NF[0])

# Show plots
plt.show()

# %% [markdown]
# A histogram on popData2019 using a Noncentral_f distribution () function is displayed, ending at around 0.3 and above 0.6 (y-axis).

# %% [markdown]
# #### Simulation continued using numpy.random.Generator.exponential on popData2019, cases and deaths variables

# %% [markdown]
# # numpy.random.Generator.exponential

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.exponential.html#numpy.random.Generator.exponential

# %% [markdown]
# Generator.exponential(scale=1.0, size=None).
#
# Draw samples from an exponential distribution.

# %% [markdown]
# ### popData2019

# %%
# Variable popData2019.
popData2019 = np.random.exponential(5, size=100)

# %%
# Execute.
popData2019
# Out:
# array([1.33465449e-02, 5.95512612e+00, 6.12242345e+00, 1.26399954e+00,
#        9.08697989e+00, 3.86873033e-01, 3.27315638e+00, 2.32312775e+01,
#        7.49108431e-01, 4.91174882e+00, 3.10739825e+00, 5.73653584e+00,
#        3.13542184e+00, 1.75390793e-01, 6.31563425e+00, 3.48269860e-01,
#        6.63436807e+00, 9.28343703e+00, 1.10191996e-01, 1.51699083e+01,
#        6.82408899e+00, 4.24140563e+00, 4.72692129e-01, 7.78026215e-01,
#        1.84064907e+01, 6.73163111e-01, 2.59134950e+00, 7.40125133e+00,
#        7.17832457e-02, 2.24016714e+00, 1.65122253e+00, 2.51366733e+00,
#        1.47991564e+00, 3.05394324e-02, 4.95872883e+00, 1.68015541e+01,
#        1.51844581e+01, 1.33402609e+00, 7.55784048e+00, 4.80952597e+00,
#        1.08009487e+01, 7.71502997e+00, 1.05629851e+01, 7.33096352e+00,
#        1.82941187e+01, 1.05730472e+01, 2.74741780e+00, 4.13849795e+00,
#        5.48367515e+00, 2.02321601e-01, 2.19204602e+00, 1.88703714e-01,
# ...

# %%
# https://stackoverflow.com/questions/47319277/generate-random-numbers-from-exponential-distribution-and-model-using-python
# Import relevant modules.
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Variable popData2019 from Covid-19 data
popData2019 = np.random.exponential(5, size=100)
# Set histogram attributes.
hist,edges = np.histogram(popData2019,bins="auto",density=True )
# Set histogram attributes.
x = edges[:-1]+np.diff(edges)/2.
# Get a plot.
plt.scatter(x,hist)
# Set histogram attributes.
func = lambda x,beta: 1./beta*np.exp(-x/beta)
# Set histogram features.
popt, pcov = curve_fit(f=func, xdata=x, ydata=hist) 
# Display popt outpout.
print(popt)

# Generate data using Numpy linspace () function.
xx = np.linspace(0, x.max(), 101)
# Get a plot.
plt.plot(xx, func(xx,*popt), ls="--", color="k", label="fit, $beta = ${}".format(popt))

# Plot labels
plt.title("A histogram on popData2019 using an Exponential distribution () function")
plt.xlabel("popData2019, on an Exponential distribution")
plt.ylabel("frequency")
# Display legend.
plt.legend()

# Show plot.
plt.show()
# Out:
# [5.73409213]

# %% [markdown]
# A histogram on popData2019 using an Exponential distribution () function is displayed showing how samples have been drowned. This is applicable for the first and second variables. Variations on y-axes while, x-axes remain constant for the 3rd and 1st variables. This trend is reversed on the second variable output: x-axis 0.0-17.5 and y-axis (0.0-20). Please see below.

# %% [markdown]
# ### cases

# %%
# Variable cases.
cases = np.random.exponential(5, size=100)

# %%
# Execute
cases
# Out:
# array([1.22492036e+01, 4.31581838e+00, 6.86907872e+00, 6.15622217e+00,
#        2.61381313e+00, 1.72977525e+00, 1.88163344e+00, 2.48283819e+00,
#        4.29996080e+00, 2.54515286e+01, 7.69450736e-01, 4.75538535e+00,
#        1.94526759e+00, 2.62003408e+00, 3.59395990e+00, 5.04919673e-01,
#        5.11774257e+00, 3.74261787e+00, 1.10954088e+00, 5.54028833e+00,
#        8.89156008e+00, 2.97566491e+00, 3.88386319e+00, 2.60803090e+00,
#        1.55441711e+00, 2.23529593e+01, 7.21842146e+00, 1.70600060e+01,
#        4.33624258e+00, 8.50499324e-01, 3.75654960e+00, 2.10283575e+01,
#        2.72259662e+00, 6.83333864e+00, 6.24605296e+00, 1.80051078e+00,
#        8.12945692e+00, 4.14638029e+01, 4.40390453e+00, 1.92818945e+00,
#        5.99394275e-01, 1.04998009e+00, 1.18662182e+00, 3.04370165e+00,
#        4.95740066e+00, 2.36990319e+00, 7.88714626e+00, 5.80221640e-01,
#        1.04031331e+00, 3.86564605e+00, 4.07946790e+00, 3.92695190e+00,
# ...

# %%
# Import relevant modules.
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# Variable cases from Covid-19 data.
cases = np.random.exponential(5, size=100)
# Set histogram attributes.
hist,edges = np.histogram(cases,bins="auto",density=True )
# Set histogram features.
x = edges[:-1]+np.diff(edges)/2.
# Get a plot.
plt.scatter(x,hist)
# Set histogram features.
func = lambda x,beta: 1./beta*np.exp(-x/beta)
# Set histogram features.
popt, pcov = curve_fit(f=func, xdata=x, ydata=hist) 
# Display popt outpout.
print(popt)
# Generate data using Numpy linspace () function.
xx = np.linspace(0, x.max(), 101)
# Get a plot
plt.plot(xx, func(xx,*popt), ls="--", color="k", label="fit, $beta = ${}".format(popt))
# Plot title and labels
plt.title("A histogram on cases using an Exponential distribution () function")
plt.xlabel("cases, on an Exponential distribution")
plt.ylabel("frequency")
# Display legend.
plt.legend()
# Show plot.
plt.show()
# Out:
# [0.49064427]

# %% [markdown]
# ### deaths

# %%
# Variable deaths.
deaths = np.random.exponential(5, size=100)

# %%
# Execute.
deaths
# Out:
# array([ 3.01751277,  4.12187917, 22.93872172,  7.77013245,  7.52414308,
#         4.89817806,  9.32146309,  5.83369515,  0.46134868,  5.94273151,
#         0.81727108,  7.95363943, 11.49123597,  2.30548207,  0.2116566 ,
#         8.23301049,  5.6378398 ,  0.75335018,  4.31906354, 18.76902473,
#         0.17040521,  7.3826311 ,  9.16175067,  4.32578029, 12.06885512,
#         8.13113437,  6.83270549,  4.37898106,  1.14032505,  2.88036972,
#         0.23281691,  0.51413105,  1.9248224 ,  6.65970037,  6.75933618,
#         0.37812973,  3.85906463,  1.31656386,  2.83717271,  9.34216618,
#         4.45983916,  4.62576052,  1.19180597, 11.51232235,  8.1279881 ,
#         0.62857161,  1.81065784,  9.92389868,  0.5094164 ,  0.33204211,
#         4.894069  ,  3.89331368,  2.56798634,  4.0364967 ,  4.83862322,
#         1.9865557 ,  1.31775899,  6.35090836,  0.17879463,  0.49811222,
#         0.90564382,  5.89944833,  7.74227565, 24.27218625, 11.29351521,
# ...

# %%
# Import relevant modules.
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# Variable deaths from Covid-19 data.
deaths = np.random.exponential(5, size=100)
# Set histogram attributes.
hist,edges = np.histogram(deaths,bins="auto",density=True )
# Set histogram features.
x = edges[:-1]+np.diff(edges)/2.
# Get a plot.
plt.scatter(x,hist)
# Set histogram features.
func = lambda x,beta: 1./beta*np.exp(-x/beta)
# Set histogram features.
popt, pcov = curve_fit(f=func, xdata=x, ydata=hist) 
# Display popt outpout.
print(popt)
# Generate data using Numpy linspace () function.
xx = np.linspace(0, x.max(), 101)
# Get a plot
plt.plot(xx, func(xx,*popt), ls="--", color="k", label="fit, $beta = ${}".format(popt))
# Plot title and labels
plt.title("A histogram on popData2019 using an Exponential distribution () function")
plt.xlabel("deaths, on an Exponential distribution")
plt.ylabel("frequency")
# Display legend.
plt.legend()
# Show plot.
plt.show()
# Out:
# [4.47524651]

# %% [markdown]
# ### Relationships between variables based on Covid-19 Dataset
#
# Use Matplotlib.pyplot and Seaborn functions to investigate relationships between variables.

# %% [markdown]
# #### cases vs deaths

# %% [markdown]
# ##### plt.plot() function

# %%
# Import Numpy and Matplotlib.pyplot
import numpy as np
import matplotlib.pyplot as plt

# Using Matplotlib.pyplot plot() function for the .loc () function to investigate relationship between variables:
# cases vs deaths.
plt.plot (df.loc[0:100,"cases"], df.loc[0:100,"deaths"], '.')
# Plot title and axes labels.
plt.title("cases vs deaths using plt.plot() function on .loc")
plt.xlabel("cases")
plt.ylabel("deaths")
# Display output.
plt.show()

# %% [markdown]
# Observing the above plot, there is an agglutination of points between 0-150 (x-axis) and 0-7(y-axis) suggesting close relationship between cases and deaths at the beginning of the pandemic. This output is reproduced with other applied functions as bellow, particularly with scatter function and regression function where an almost simple regression line is displayed within the plot to suggest this relationship.

# %%
# Using Matplotlib.pyplot plot() function for the .iloc () function to investigate relationship between variables:
# cases vs deaths.
plt.plot (df.iloc[0:100, 4], df.iloc[0:100, 5], '.')
# Plot title and axes labels.
plt.title("cases vs deaths using plt.plot() function on .iloc")
plt.xlabel("cases")
plt.ylabel("deaths")
# Display plot.
plt.show()

# %% [markdown]
# ##### plt.scatter() function

# %%
# Using Matplotlib.pyplot scatter() function for the .loc()function to investigate relationship between variables:
# cases vs deaths.
plt.scatter(df.loc[0:100,"cases"], df.loc[0:100,"deaths"])
# Plot title and axes labels.
plt.title("cases vs deaths using scatter.plot() function on .loc")
plt.xlabel("cases")
plt.ylabel("deaths")
# Display plot.
plt.show()

# %%
# Using Matplotlib.pyplot scatter() function for the .iloc()function to investigate relationship between variables:
# cases vs deaths.

plt.scatter(df.iloc[0:100,4], df.iloc[0:100,5])
# Plot title and axes labels.
plt.title("cases vs deaths using scatter.plot() function on .iloc")
plt.xlabel("cases")
plt.ylabel("deaths")
# Display plot.
plt.show()

# %% [markdown]
# #### Seaborn function

# %% [markdown]
# ##### sns.regplot()

# %%
# Using seaborn regression plot () for the .loc()to investigate relationship between variables:
# cases vs deaths.
sns.regplot(df.loc[0:100,"cases"], df.loc[0:100,"deaths"])
# PLot title and axes labels.
plt.title("cases vs deaths using sns.regplot() function on .loc")
plt.xlabel("cases")
plt.ylabel("deaths")
# Display plot.
plt.show()

# %%
# Using seaborn regression plot () for the .iloc function to investigate relationship between variables:
# cases vs deaths.
sns.regplot(df.iloc[0:100,4], df.iloc[0:100,5])
# Plot title and axes labels.
plt.title("cases vs deaths using sns.regplot() function on .iloc")
plt.xlabel("cases")
plt.ylabel("deaths")
# Display plot.
plt.show()
# Out:
# Text(0, 0.5, 'deaths')

# %% [markdown]
# #### popData2019 vs  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000

# %% [markdown]
# ##### plt.plot() function

# %%
# Using Matplotlib.pyplot plot() function for the .loc () function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
plt.plot (df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"], '.')
# Plot title and axes labels.
plt.title("popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000, plt.plot() on .loc")
plt.xlabel("popData2019")
plt.ylabel("Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
# Display plot.
plt.show()

# %% [markdown]
# Vertical dots are positioned near the middle of the plot at 3.80 1e7(x-axis) and around 7(y-axis). This is reproduced on all plots below regardless of the function used.

# %%
# Using Matplotlib.pyplot plot() function for the .iloc() function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
plt.plot (df.iloc[0:100, 9], df.iloc[0:100, 11], '.')
# Plot title and axes labels.
plt.title("popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000, plt.plot() on .iloc")
plt.xlabel("popData2019")
plt.ylabel("Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
# Display plot.
plt.show()

# %% [markdown]
# ##### plt.scatter() function

# %%
# Using Matplotlib.pyplot scatter() function for the .loc()function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
plt.scatter(df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"])
# Plot title and axes labels.
plt.title("popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 plt.scatter() on .loc")
plt.xlabel("popData2019")
plt.ylabel("Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
# Show plot.
plt.show()

# %%
# Using Matplotlib.pyplot scatter() function for the .iloc()function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
plt.scatter(df.iloc[0:100,9], df.iloc[0:100,11])
# Plot title and axes labels.
plt.title("popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 plt.scatter() on .iloc")
plt.xlabel("popData2019")
plt.ylabel("Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
# Show plot.
plt.show()

# %% [markdown]
# #### Seaborn function

# %% [markdown]
# #### sns.regplot()

# %%
# Using seaborn regression plot () for the .loc() to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
sns.regplot(df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"])
# Plot title and axes labels.
plt.title("popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 sns.regplot() on .loc")
plt.xlabel("popData2019")
plt.ylabel("Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
# Show plot.
plt.show()

# %%
# Using seaborn regression plot () for the .iloc function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
sns.regplot(df.iloc[0:100,9], df.iloc[0:100,11])
# Plot title and axes labels.
plt.title("popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 sns.regplot() on .iloc")
plt.xlabel("popData2019")
plt.ylabel("Cumulative_number_for_14_days_of_COVID-19_cases_per_100000")
#Show plot.
plt.show()

# %% [markdown]
# ### Research detail

# %% [markdown]
# #### A real-world phenomenon

# %% [markdown]
# For the purpose of the project on the Programming for Data Analysis 2020, I have chosen the Coronavirus disease 2019
# (COVID-19) pandemic as a real-world phenomenon of interest.

# %% [markdown]
# #### About the dataset

# %% [markdown]
# For the purpose of this project, I use the COVID-19 Data Worldwide dataset.
#
# The COVID-19 Coronavirus data is a dataset containing data on the geographic distribution of COVID-19 cases worldwide [1]. It contains twelve variables including dateRep, day, month, year, cases, deaths, countriesAndTerritories, geold, countryterritoryCode, popData2019, continentExp, and Cumulative_number_for_14_days_of_COVID-19_cases_per_100000. It has 57641(Excel format) entries. The types of variables are as follows seven numerical, four string and one ordinal.

# %% [markdown]
# #### Accessing the dataset We had a copy of dataset on our files

# %% [markdown]
# The dataset is accessible at the EU Portal webpage [1].

# %% [markdown]
# #### Relevant Python modules

# %% [markdown]
# Import relevant Python modules to perform multiple operations pertaining to this project: Pandas (data analysis and manipulation), Numpy (numerical operations), Matplotlib.pyplot (plots) and Seaborn (data visualisation).

# %% [markdown]
# #### Method of dataset access using Pandas DataFrame () function

# %% [markdown]
# Use Pandas DataFrame () function as df = pd.read_csv ("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv") and call the df () function as df to access the entire dataset. A DataFrame outputs a tabular, spreadsheet-like data representation, that has a well-organised numeric, string, Boolean, to name but a few, columns. The DataFrame function has a row and column index [5].

# %% [markdown]
# #### Summarising the dataset

# %% [markdown]
# Use the following functions DataFrame functions to summarise the dataset: df. head(), df.tail() and df.describe(). The first function outputs columns in number of twelve and five rows starting by index 0 as 1. The second function outputs the last five rows and all twelve columns. The third function outputs the description of the dataset summary including count, mean, std, min, 25%, average (50%), 75% and max.

# %% [markdown]
# #### Selection of four variables of interest and one hundred points

# %% [markdown]
# For the prupose of this project, I have selected the following four variables of interest including cases, deaths, popData2019 and cumulative_number_for_14_days_of_COVID-19_cases_per_100000, and one hundred entries (points). All four variables are numerical. Use df.loc[0:100,["cases","deaths","popData2019", “Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"]]. Use the .iloc() function to display all variables and their values as follows:
# df.iloc[0:100, 4] for the first variable of chosen; df.iloc[0:100, 5] for the second variable of chosen; df.iloc[0:100, 9] for the third variable of chosen and df.iloc[0:100, 11] for the fourth variable of chosen.

# %% [markdown]
# #### Investigating variables

# %% [markdown]
# Using Matplotlib.pyplot hist() function for the .loc () and .iloc functions to display histograms for each variable. plt.hist(df.loc[0:100,"cases"]) and plt.hist(df.iloc[0:100,"cases"]) for cases, both functions .loc and .iloc produce the same outputs. Histogram is “accurate method for the graphical representation of numerical data distribution” (Geeksforgeeks, 2020) [2]. plt.hist(df.loc[0:100,"deaths"]) and plt.hist(df.iloc[0:100,5]) for deaths. They produce the same results. plt.hist(df.loc[0:100,"popData2019"] and plt.hist(df.iloc[0:100,9]) for the popData2019. They provide identical outputs. plt.hist(df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"]) and plt.hist(df.iloc[0:100,11]) for Cumulative_number_for_14_days_of_COVID-19_cases_per_100000. They also produce the same results.

# %% [markdown]
# ##### Analysis

# %% [markdown]
# A bin between 0-50 scores above 40 frequency suggesting a huge distribution of cases at that level. .loc() function and .iloc() function produce the same outcome on Covid-19 cases as on plots above: a bin between 0-50 scores above 40 frequency suggesting a huge distribution of cases at that level. A bin between 0-5 scores above 50 frequency, suggesting a huge distribution of deaths at that level. .loc() function and .iloc() function produce the same outcome on Covid-19 deaths as on plots above: a bin between 0-5 scores above 50 frequency suggesting a huge distribution of deaths at that level. A unique bin between 7.0-7.2 scores above 100 frequency, suggesting a huge distribution of popData2019 at that level. .loc() function and .iloc() function produce the same outcome on Covid-19 popData2019 as on plots above: a unique bin between 7.0-7.2 scores above 100 frequency, suggesting a huge distribution of popData2019 at that level. A bin between 1 to 2 scores above 25 frequency suggesting a huge distribution of Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 at that level. .loc() function and .iloc() function produce the same outcome on Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 as on the above plots: a bin between 1 to 2 scores above 25 frequency, suggesting a huge distribution of Cumulative_number_for_14_days_of_COVID-19_cases_per_100000 at that level.

# %% [markdown]
# #### Distributions based on data simulation

# %% [markdown]
# I used the following Numpy functions to investigate distributions between variables. These include: Numpy.random.Genenator.gumbel() function, numpy.random.Generator.hypergeometric() function, numpy.random.Generator.logistic() function, numpy.random.Generator.noncentral_chisquare() function and numpy.random.Generator.noncentral_f() function. Gumble distribution function(Draws  samples from distributions) is used for the following variables: cases, deaths and popData2019 as cases = rng.gumbel(mu, beta, 100) to generate an array and  count, bins, ignored = plt.hist(cases, 30, density=True) to display a histogram ( please see additional line of code above and this applies for the other variables); deaths = rng.gumbel(mu, beta, 100) to generate an array and count, bins, ignored = plt.hist(deaths, 30, density=True) to display a histogram; and popData2019 = rng.gumbel(mu, beta, 100) to generate an array and count, bins, ignored = plt.hist(popData2019, 30, density=True) to output a histogram. Following the same process as above, I used hypergeometric() function (Draw sample from a Hypergeometric distribution) for the variable cases, logistic () function (Draw sample from logistic distribution) for the variable deaths and concental _chi-square() function (Draw samples from a noncentral chi-square distribution) for the variable popData2019 and noncentral_() function (Draw samples from the noncentral F distribution for the 3rd variable (popData2019). We could not perform distributions operations with the 4th variable Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.

# %% [markdown]
# ##### Analysis

# %% [markdown]
# A bell-curve plot is displayed on the histogram in which one bin situated at between -0.1 to 0.0 bins reaches at almost 7 frequency at y(axis) from simulated cases. This is reproduced on the outputs of other variables while using the distributions function gumble(). A hypergeometric distribution is displayed on simulated cases with a rise of pick at 10.00 (x-axis). A Logistic distribution is displayed on simulated deaths with a rise situated between 8 and 10(x-axis) and reaching 8 (y-axis). A histogram on popData2019 using a Noncentral_chisquare distribution() function is displayed with significant rise at 20 (x-axis). A histogram on popData2019 using a Noncentral_f distribution() function is displayed, ending at around 0.3 and above 0.6 (y-axis). A histogram on popData2019 using an Exponential distribution() function is displayed showing how samples have been drowned. This is applicable for the first and second variables. Variations on y-axes while, x-axes remain constant for the 3rd and 1st variables. This trend is reversed on the second variable output: x-axis 0.0-17.5 and y-axis (0.0-20).

# %% [markdown]
# #### Simulation continued

# %% [markdown]
# I use the Numpy.random.Generator.exponential function. This function is used to draw samples from an exponential distribution. This function is used on popData2019, cases and deaths variables.For the 3rd variable use popData2019 = np.random.exponential (5, size=100) to generate an array, and popData2019 = np.random.exponential (5, size=100) (additional line of code is required as above, and this is applicable for the two other variables) to output the exponential function plot and simulation of the dataset. Following the same process, use cases = np.random.exponential (5, size=100) and cases = np.random.exponential (5, size=100) for the 1st variable. Use deaths = np.random.exponential (5, size=100) and deaths = np.random.exponential (5, size=100) for the 2nd variable.

# %% [markdown]
# #### Analysis

# %% [markdown]
# An exponential distribution is displayed based on simulated dataset. This is applicable for the first and second variables. Variations on y-axes while x-axes remain constant for the 3rd and 1st variables. This trend is reversed on the second variable output: x-axis 0.0-17.5 and y-axis (0.0-20). Please see as above.

# %% [markdown]
# #### Relationships between variables

# %% [markdown]
# Use Matplotlib.pyplot and Seaborn functions to investigate relationships between variables. These include Matplotlib.pyplot plt.plot (), plt.scatter () and sns.regplot () function for the .loc () and .iloc functions to display relationships between variables.
# For cases versus(v) deaths: plt.plot (df.loc[0:100,"cases"], df.loc[0:100,"deaths"], '.'); plt.plot (df.iloc[0:100, 4], df.iloc[0:100, 5], '.'); plt.scatter(df.loc[0:100,"cases"], df.loc[0:100,"deaths"]), plt.scatter(df.iloc[0:100,"cases"], df.iloc[0:100,"deaths"]), and sns.regplot(df.loc[0:100,"cases"], df.loc[0:100,"deaths"]), sns.regplot(df.iloc[0:100,4], df.iloc[0:100,5]).
# For popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000: plt.plot (df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"], '.'); plt.plot (df.iloc[0:100, 9], df.iloc[0:100, 11], '.'), plt.scatter(df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"]); plt.scatter(df.iloc[0:100,9], df.iloc[0:100,11]); and sns.regplot(df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"]);  and sns.regplot(df.iloc[0:100,9], df.iloc[0:100,11]).

# %% [markdown]
# ###### Analysis

# %% [markdown]
# Observing the output of the relationship between cases and deaths, there is an agglutination of points between 0-150 (x-axis) and 0-7(y-axis) suggesting close relationship between cases and deaths at the beginning of the pandemic. This output is reproduced with other applied functions as above, particularly with scatter function and regression function, where an almost simple regression line is displayed within the plot to suggest this relationship.
# Vertical dots are positioned near the middle of the plot at 3.80 1e7 (x-axis) and around 7(y-axis). This is reproduced on all plots as above regardless of the function used.

# %% [markdown]
# # End

# %% [markdown]
# <br>
