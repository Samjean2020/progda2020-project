# %% [markdown]
# # Programming for Data Analysis

# %% [markdown]
# <cr>

# %% [markdown]
# ## Project 2020

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# For this project you must create a data set by simulating a real-world phenomenon of
# your choosing. You may pick any phenomenon you wish – you might pick one that is
# of interest to you in your personal or professional life. Then, rather than collect data
# related to the phenomenon, you should model and synthesise such data using Python.
# We suggest you use the numpy.random package for this purpose.
# Specifically, in this project you should:
# • Choose a real-world phenomenon that can be measured and for which you could
# collect at least one-hundred data points across at least four different variables.
# • Investigate the types of variables involved, their likely distributions, and their
# relationships with each other.
# • Synthesise/simulate a data set as closely matching their properties as possible.
# • Detail your research and implement the simulation in a Jupyter notebook – the
# data set itself can simply be displayed in an output cell within the notebook.
# Note that this project is about simulation – you must synthesise a data set. Some
# students may already have some real-world data sets in their own files. It is okay to
# base your synthesised data set on these should you wish (please reference it if you do),
# but the main task in this project is to create a synthesised data set.

# %% [markdown]
# ## Introduction

# %% [markdown]
#  These are my solutions in relation to the above problem statement. The author is Jean Bonsenge. Email: g00387887@gmit.ie

# %% [markdown]
# ## References
#
# [1]EU Open Data Portal (2020) “COVID-19 Coronavirus data”.
#
# https://data.europa.eu/euodp/en/data/dataset/covid-19-coronavirus-data/resource/260bbbde-2316-40eb-aec3-7cd7bfc2f590(Accessed 10/12/2020)
#
# [2] Geeksforgeeks(2020)"Plotting Histogram in Python using Matplotlibhttps"://www.geeksforgeeks.org/plotting-histogram-in-python-using-matplotlib/
#
# [3] Geeksforgeeks(2020) "Python | Pandas Extracting rows using .loc[]: https://www.geeksforgeeks.org/python-pandas-extracting-rows-using-loc/
#
# [4] Geeksforgeeks(2020) "Python | Extracting rows using Pandas .iloc[]: https://www.geeksforgeeks.org/python-extracting-rows-using-pandas-iloc/
#
# [5] McKinney W. (2013) “Python for Data Analysis"(Sebastopol: O’Reilly Media, Inc)
#
#
# [6]Numpy(2020)"Random Generator"https://numpy.org/doc/stable/reference/random/generator.html#distributions(Accessed 15/12/2020)
#
# [7] Numpy (2020) "numpy.random.Generator.gumbel"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.gumbel.html#numpy.random.Generator.gumbel
#
# [8] Numpy(2020) "numpy.random.Generator.hypergeometric"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.hypergeometric.html#numpy.random.Generator.hypergeometric
#
# [9] Numpy (2020) "numpy.random.Generator.logistic"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.logistic.html#numpy.random.Generator.logistic
# [10] Numpy (2020) "numpy.random.Generator.noncentral_chisquare"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_chisquare.html#numpy.random.Generator.noncentral_chisquare
#
# [11] Numpy(2020) "numpy.random.Generator.noncentral_f"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_f.html#numpy.random.Generator.noncentral_f
#
# [12] Numpy(2020)"numpy.random.Generator.logistic"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.logistic.html#numpy.random.Generator.logistic
# [13] Numpy(2020) "numpy.random.Generator.noncentral_chisquare"
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_chisquare.html#numpy.random.Generator.noncentral_chisquare

# %% [markdown]
# ## Development

# %% [markdown]
# ### A real-world phenomenon: Coronavirus disease 2019 (COVID-19)

# %%
# Magic command in Ipython displaying the output.  
# %matplotlib inline

# Numercial arrays and fitting lines
import numpy as np
# Plots.
import matplotlib.pyplot as plt
# Data visualisation
import seaborn as sns
# Nicer plot style.
plt.style.use('ggplot')
# Bigger plots.
plt.rcParams['figure.figsize'] = 14, 10

#Import pandas as pd for data analysis and manipulation.
import pandas as pd
# Pandas DataFrame() function to read the csv file.
df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")

# %% [markdown]
# ### About the dataset
# This dataset is about Covid-19 worldwide issued by the EU Open Data Portal[1].
#
# A csv dataset that contains 57640 rows and 12 columns(variables). See the output below.

# %%
# Call DataFrame()function.
df
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0      24/11/2020   24     11  2020    246      17             Afghanistan
# 1      23/11/2020   23     11  2020    252       8             Afghanistan
# 2      22/11/2020   22     11  2020    154      12             Afghanistan
# 3      21/11/2020   21     11  2020    232      25             Afghanistan
# 4      20/11/2020   20     11  2020    282       5             Afghanistan
# ...           ...  ...    ...   ...    ...     ...                     ...
# 57635  25/03/2020   25      3  2020      0       0                Zimbabwe
# 57636  24/03/2020   24      3  2020      0       1                Zimbabwe
# 57637  23/03/2020   23      3  2020      0       0                Zimbabwe
# 57638  22/03/2020   22      3  2020      1       0                Zimbabwe
# 57639  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# ...

# %% [markdown]
# ### Dataset Summary

# %%
# Output the five first rows and all twelve variables.
df.head()
# Out:
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  24/11/2020   24     11  2020    246      17             Afghanistan    AF
# 1  23/11/2020   23     11  2020    252       8             Afghanistan    AF
# 2  22/11/2020   22     11  2020    154      12             Afghanistan    AF
# 3  21/11/2020   21     11  2020    232      25             Afghanistan    AF
# 4  20/11/2020   20     11  2020    282       5             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           6.713675
# 1                                           6.655844
# ...

# %%
# Output the last five rows and twelve variables.
df.tail()
# Out:
#           dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 57635  25/03/2020   25      3  2020      0       0                Zimbabwe
# 57636  24/03/2020   24      3  2020      0       1                Zimbabwe
# 57637  23/03/2020   23      3  2020      0       0                Zimbabwe
# 57638  22/03/2020   22      3  2020      1       0                Zimbabwe
# 57639  21/03/2020   21      3  2020      1       0                Zimbabwe
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 57635    ZW                  ZWE   14645473.0       Africa
# 57636    ZW                  ZWE   14645473.0       Africa
# 57637    ZW                  ZWE   14645473.0       Africa
# 57638    ZW                  ZWE   14645473.0       Africa
# 57639    ZW                  ZWE   14645473.0       Africa
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 57635                                                NaN
# ...

# %%
# Output a summary of the dataset: count, mean, std, min, 25%, average(50%), 75% and max.
df.describe()
# Out:
#                 day         month          year          cases        deaths  \
# count  57640.000000  57640.000000  57640.000000   57640.000000  57640.000000
# mean      15.786103      6.724774   2019.998838    1028.929441     24.248300
# std        8.745097      2.767141      0.034074    5836.617972    125.652523
# min        1.000000      1.000000   2019.000000   -8261.000000  -1918.000000
# 25%        8.000000      5.000000   2020.000000       0.000000      0.000000
# 50%       16.000000      7.000000   2020.000000      14.000000      0.000000
# 75%       23.000000      9.000000   2020.000000     237.000000      4.000000
# max       31.000000     12.000000   2020.000000  196117.000000   4928.000000
#
#         popData2019  \
# count  5.753700e+04
# mean   4.134196e+07
# std    1.540102e+08
# min    8.150000e+02
# 25%    1.324820e+06
# 50%    7.813207e+06
# 75%    2.860872e+07
# max    1.433784e+09
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# ...

# %% [markdown]
# ### Selection of four variables of interest

# %% [markdown]
# ##### .loc () function

# %%
# With .loc function select four variables of interest:cases, deaths, popData2019 and cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
# Select 100 rows or points from 0-100.
df.loc[0:100,["cases", "deaths","popData2019", "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"]]
# Out:
#      cases  deaths  popData2019  \
# 0      246      17   38041757.0
# 1      252       8   38041757.0
# 2      154      12   38041757.0
# 3      232      25   38041757.0
# 4      282       5   38041757.0
# ..     ...     ...          ...
# 96     160       8   38041757.0
# 97       0       0   38041757.0
# 98       3       0   38041757.0
# 99      45       5   38041757.0
# 100    120       7   38041757.0
#
#      Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                             6.713675
# 1                                             6.655844
# 2                                             6.203709
# 3                                             6.130106
# 4                                             5.672714
# ..                                                 ...
# 96                                            2.268560
# 97                                            2.024092
# 98                                            2.239644
# ...

# %% [markdown]
# #### .iloc () function
#
# ### cases

# %%
# Display the fourth variable and its values using .iloc() function.
df.iloc[0:100, 4]
# Out:
# 0     246
# 1     252
# 2     154
# 3     232
# 4     282
#      ...
# 95     97
# 96    160
# 97      0
# 98      3
# 99     45
# Name: cases, Length: 100, dtype: int64

# %% [markdown]
# ### deaths

# %%
# Display the fifth variable and its values using .iloc() function.
df.iloc[0:100, 5]
# Out:
# 0     17
# 1      8
# 2     12
# 3     25
# 4      5
#       ..
# 95     2
# 96     8
# 97     0
# 98     0
# 99     5
# Name: deaths, Length: 100, dtype: int64

# %% [markdown]
# ### popData

# %%
# Display the ninth variable and its values using .iloc() function.
df.iloc[0:100, 9]
# Out:
# 0     38041757.0
# 1     38041757.0
# 2     38041757.0
# 3     38041757.0
# 4     38041757.0
#          ...
# 95    38041757.0
# 96    38041757.0
# 97    38041757.0
# 98    38041757.0
# 99    38041757.0
# Name: popData2019, Length: 100, dtype: float64

# %% [markdown]
# ### Cumulative_number_for_14_days_of_COVID-19_cases_per_100000

# %%
# Display the eleventh variable and its values using .iloc() function.
df.iloc[0:100, 11]
# Out:
# 0     6.713675
# 1     6.655844
# 2     6.203709
# 3     6.130106
# 4     5.672714
#         ...
# 95    2.415766
# 96    2.268560
# 97    2.024092
# 98    2.239644
# 99    2.329020
# Name: Cumulative_number_for_14_days_of_COVID-19_cases_per_100000, Length: 100, dtype: float64

# %% [markdown]
# ### Investigating variables

# %% [markdown]
# ### Types of variables

# %% [markdown]
# #### Cases

# %%
# Using Matplotlib.pyplot hist() function for the .loc () function to display an histogram for the variable:
# "cases".
plt.hist(df.loc[0:100,"cases"])
plt.show()

# %%
# Using Matplotlib.pyplot hist() function for the .iloc () function to display an histogram for the variable:
# "cases".
plt.hist(df.iloc[0:100,4])
plt.show()

# %% [markdown]
# #### Deaths

# %%
# Using Matplotlib.pyplot hist() function for the .loc () function to display an histogram for the variable:
# "deaths".
plt.hist(df.loc[0:100,"deaths"])
plt.show()

# %%
# Using Matplotlib.pyplot hist() function for the .iloc () function to display an histogram for the variable:
# "deaths".

plt.hist(df.iloc[0:100,5])
plt.show()

# %% [markdown]
# #### PopData2019

# %%
# Using Matplotlib.pyplot hist() function for the .loc () function to display an histogram for the variable:
# "popData2019".

plt.hist(df.loc[0:100,"popData2019"])
plt.show()

# %%
# Using Matplotlib.pyplot hist() function for the .iloc () function to display an histogram for the variable:
# "popData2019".

plt.hist(df.iloc[0:100,9])
plt.show()

# %% [markdown]
# #### Cumulative_number_for_14_days_of_COVID-19_cases_per_100000

# %%
# Using Matplotlib.pyplot hist() function for the .loc () function to display an histogram for the variable:
# "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000".

plt.hist(df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"])
plt.show()

# %%
# Using Matplotlib.pyplot hist() function for the .iloc () function to display an histogram for the variable:
# "Cumulative_number_for_14_days_of_COVID-19_cases_per_100000".

plt.hist(df.iloc[0:100,11])
# Out:
# (array([20., 26., 19.,  9.,  7.,  8.,  4.,  2.,  1.,  4.]),
#  array([0.66505866, 1.26992031, 1.87478197, 2.47964362, 3.08450527,
#         3.68936693, 4.29422858, 4.89909023, 5.50395188, 6.10881354,
#         6.71367519]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Distributions

# %% [markdown]
# Numpy(2020)"Random Generator"https://numpy.org/doc/stable/reference/random/generator.html#distributions(Accessed 15/12/2020)

# %% [markdown]
# ### numpy.random.Generator.gumbel

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.gumbel.html#numpy.random.Generator.gumbel
# numpy.random.Generator.gumbel
#
# Draw samples from the distribution:

# %%
# Draw samples from the distribution:
rng = np.random.default_rng()
mu, beta = 0, 0.1 # location and scale
cases = rng.gumbel(mu, beta, 100)

# %%
cases
# Out:
# array([-7.26449375e-02,  1.18195393e-01, -6.81701810e-02,  2.64375825e-01,
#         7.12626680e-02,  1.97754459e-01,  7.72483003e-02, -2.03942327e-03,
#        -6.75324331e-02, -1.33622918e-01,  1.38871871e-01,  1.36991438e-01,
#        -1.08179429e-01,  1.16681859e-01,  3.46697575e-01, -1.85776776e-01,
#         1.06220173e-01,  3.24369569e-02,  2.48523709e-01,  1.65392315e-01,
#        -9.30010258e-03,  6.51541791e-02,  2.31105325e-01,  1.47845346e-03,
#        -1.16441484e-01, -6.36993636e-03,  1.26880472e-01, -6.62169395e-02,
#         7.58125147e-02,  2.70496187e-02,  4.15665814e-02, -8.11979978e-02,
#         1.61794403e-01,  1.39190410e-02, -6.71795873e-02, -1.10180405e-01,
#         3.14278747e-02,  4.41123010e-02, -4.34269133e-02,  1.63899901e-01,
#         2.84971386e-02, -1.61961200e-01,  6.84247818e-02,  1.79952917e-01,
#        -2.28739553e-02,  1.25038910e-01,  1.20720572e-01, -6.50087623e-02,
# ...

# %%
len(cases)
# Out:
# 100

# %%
#Display the histogram of the samples, along with the probability density function:
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(cases, 30, density=True)
plt.plot(bins, (1/beta)*np.exp(-(bins - mu)/beta)
         * np.exp( -np.exp( -(bins - mu) /beta) ), linewidth=2, color='b')
plt.show()

# %%
rng = np.random.default_rng()
mu, beta = 0, 0.1 # location and scale
deaths = rng.gumbel(mu, beta, 100)

# %%
deaths
# Out:
# array([-1.15494439e-01, -1.49281599e-02,  3.18640818e-01,  1.22272765e-01,
#         4.70143947e-02,  1.93469864e-01,  1.96026837e-02, -1.56733254e-04,
#        -3.82041600e-02,  3.33705692e-01,  2.10149376e-01, -2.67226220e-02,
#         1.40854172e-01,  3.92620662e-01,  1.81830771e-01,  6.60215414e-02,
#         5.75728869e-02, -8.93602944e-02,  3.34884375e-02,  4.31099218e-02,
#         1.29648141e-02, -1.39876936e-01, -9.33224536e-02, -2.35823518e-02,
#        -1.83490791e-01,  1.43786581e-01,  9.89708559e-02, -2.41149208e-02,
#         4.94112480e-02, -4.83644293e-02,  9.14211623e-02,  6.57292248e-02,
#        -4.32467412e-02, -4.58966436e-02, -2.02902252e-02, -6.87332573e-03,
#         1.21842438e-02, -1.49350575e-01,  1.14755207e-02,  8.40914971e-02,
#        -3.11377740e-02, -1.07692147e-01,  1.80133519e-01, -1.10920725e-02,
#         1.13851101e-01,  6.39668721e-02,  1.25883094e-01,  6.53822349e-02,
# ...

# %%
len(deaths)
# Out:
# 100

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(deaths, 30, density=True)
plt.plot(bins, (1/beta)*np.exp(-(bins - mu)/beta)
         * np.exp( -np.exp( -(bins - mu) /beta) ), linewidth=2, color='b')
plt.show()

# %%
rng = np.random.default_rng()
mu, beta = 0, 0.1 # location and scale
popData2019 = rng.gumbel(mu, beta, 100)

# %%
popData2019
# Out:
# array([ 0.27318888,  0.32285113, -0.01330843,  0.11525684, -0.04930094,
#         0.11699502,  0.02912626, -0.05848356, -0.0047122 ,  0.26247165,
#         0.07095766,  0.12192139, -0.04905545,  0.07708398,  0.27977091,
#        -0.14952504,  0.11693995,  0.03449388,  0.12597328,  0.03579601,
#         0.0034337 ,  0.11834421,  0.33683889,  0.0582549 , -0.08231776,
#         0.15083514,  0.28804873,  0.58901964, -0.09699483, -0.13402913,
#        -0.00897293,  0.23898273, -0.04648719,  0.1022383 ,  0.15303537,
#         0.12590707,  0.11760566,  0.1052852 ,  0.09667   ,  0.21485197,
#         0.48101943,  0.14174366, -0.03228866, -0.02198882, -0.0452833 ,
#         0.07252637, -0.03521665,  0.06857627, -0.03504639,  0.22138158,
#         0.16794251, -0.16725239,  0.08340302, -0.04439973,  0.04399734,
#         0.07135225, -0.06758914, -0.00581646,  0.18091618,  0.13412201,
#         0.0622552 , -0.00202757, -0.04454285,  0.13004309,  0.27381472,
# ...

# %%
len(popData2019)
# Out:
# 100

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(popData2019, 30, density=True)
plt.plot(bins, (1/beta)*np.exp(-(bins - mu)/beta)
         * np.exp( -np.exp( -(bins - mu) /beta) ), linewidth=2, color='b')
plt.show()

# %% [markdown]
# ### numpy.random.Generator.hypergeometric

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.hypergeometric.html#numpy.random.Generator.hypergeometric
#
# hypergeometric(ngood, nbad, nsample[, size])

# %%
cases = np.random.hypergeometric(good, bad, samp, 100)

# %%
cases
# Out:
# array([10, 10, 10, 10, 10,  9,  9, 10, 10, 10,  9, 10, 10, 10, 10, 10, 10,
#        10, 10, 10, 10,  9, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#        10, 10, 10, 10, 10, 10, 10, 10, 10, 10,  9, 10,  9, 10, 10, 10, 10,
#         9, 10, 10, 10, 10,  9, 10,  9,  9, 10, 10,  9, 10,  8, 10, 10,  9,
#        10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,  9, 10, 10, 10, 10,
#        10, 10, 10, 10, 10, 10, 10, 10, 10,  9, 10, 10, 10, 10, 10])

# %%
# hypergeometric(ngood, nbad, nsample[, size])

# This function is used to draw sample from a Hypergeometric distribution.

# Example:

df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")
import pandas as pd
import numpy as np  
good, bad, samp = 100, 2, 10  
cases = np.random.hypergeometric(good, bad, samp, 100)  
plt.hist(cases)  
plt.show()

# %%
#https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.hypergeometric.html#numpy.random.Generator.hypergeometric
from matplotlib.pyplot import hist

df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")

rng = np.random.default_rng()
ngood, nbad, nsamp = 100, 2, 10

cases = rng.hypergeometric(ngood, nbad, nsamp, 100)

hist(cases)
# Out:
# (array([22.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 78.]),
#  array([ 9. ,  9.1,  9.2,  9.3,  9.4,  9.5,  9.6,  9.7,  9.8,  9.9, 10. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### numpy.random.Generator.logistic
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.logistic.html#numpy.random.Generator.logistic

# %% [markdown]
# Generator.logistic(loc=0.0, scale=1.0, size=None)

# %%
# logistic([loc, scale, size])

# This function is used to draw sample from logistic distribution.
# Draw samples from a logistic distribution.

# Samples are drawn from a logistic distribution with specified parameters,
# loc(location or mean, also median), and scale (>0).

df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")
import numpy as np  
import matplotlib.pyplot as plt  
location, scale = 10, 1  
deaths = np.random.logistic(location, scale, 100)  
count, bins, ignored = plt.hist(cases, bins=50)  
count  
bins  
ignored  
plt.show()

# %% [markdown]
# ### numpy.random.Generator.noncentral_chisquare

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_chisquare.html#numpy.random.Generator.noncentral_chisquare

# %% [markdown]
# Generator.noncentral_chisquare(df, nonc, size=None)

# %%
# Draw values from the distribution and plot the histogram
df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")
rng = np.random.default_rng()
import matplotlib.pyplot as plt
popData2019 = plt.hist(rng.noncentral_chisquare(3, 20, 10000),bins=200, density=True)
plt.show()

# %% [markdown]
# # numpy.random.Generator.noncentral_f

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_f.html#numpy.random.Generator.noncentral_f

# %% [markdown]
# Generator.noncentral_f(dfnum, dfden, nonc, size=None).
#
# Draw samples from the noncentral F distribution.

# %%
#https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.noncentral_f.html#numpy.random.Generator.noncentral_f 

df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")

rng = np.random.default_rng()
dfnum = 3 # between group deg of freedom
dfden = 20 # within groups degrees of freedom
nonc = 3.0
popData2019 = rng.noncentral_f(dfnum, dfden, nonc, 1000000)
NF = np.histogram(popData2019, bins=50, density=True)
c_vals = rng.f(dfnum, dfden, 1000000)
F = np.histogram(c_vals, bins=50, density=True)
import matplotlib.pyplot as plt
plt.plot(F[1][1:], F[0])
plt.plot(NF[1][1:], NF[0])
plt.show()

# %% [markdown]
# # Simulation

# %% [markdown]
# # numpy.random.Generator.exponential

# %% [markdown]
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.exponential.html#numpy.random.Generator.exponential

# %% [markdown]
# Generator.exponential(scale=1.0, size=None).
#
# Draw samples from an exponential distribution.

# %% [markdown]
# ### popData2019

# %%
df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")
popData2019 = np.random.exponential(5, size=100)

# %%
popData2019
# Out:
# array([4.41964318e+00, 2.41147735e+00, 6.53599589e+00, 2.65861605e+00,
#        7.42536308e+00, 6.30758389e+00, 3.62459078e+00, 2.15985564e+00,
#        1.74196320e+00, 2.70395646e+00, 2.85913782e+00, 1.56946278e+01,
#        4.39379375e+00, 7.89362125e+00, 3.76030025e+00, 2.45547272e+01,
#        2.58551057e+01, 4.44158156e+00, 4.54658935e+00, 5.71095324e+00,
#        1.44043191e-02, 3.69968096e+00, 6.55167767e+00, 2.15675045e+00,
#        2.43258413e+01, 1.18236363e+01, 1.17007055e+01, 1.80796376e+00,
#        2.21125894e+01, 3.16576716e+00, 4.44170708e+00, 5.15501771e+00,
#        3.24444233e+00, 1.45385696e+00, 8.42967191e+00, 7.04639639e+00,
#        8.26648035e+00, 4.25266669e-01, 9.33391283e-01, 5.36084736e+00,
#        5.90485242e+00, 1.10017503e+00, 3.54586607e+00, 1.14402558e+01,
#        1.02201051e+01, 1.30324258e+01, 1.86286020e+01, 1.31717801e+00,
#        7.26342316e+00, 8.86709291e+00, 3.58751552e+00, 2.49378107e+01,
# ...

# %%
# https://stackoverflow.com/questions/47319277/generate-random-numbers-from-exponential-distribution-and-model-using-python

# Exponential distribution examples 

# pandas - Generate random numbers from exponential distribution and model using python - Stack Overflow

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

popData2019 = np.random.exponential(5, size=100)

hist,edges = np.histogram(popData2019,bins="auto",density=True )

x = edges[:-1]+np.diff(edges)/2.
plt.scatter(x,hist)

func = lambda x,beta: 1./beta*np.exp(-x/beta)

popt, pcov = curve_fit(f=func, xdata=x, ydata=hist) 

print(popt)

xx = np.linspace(0, x.max(), 101)
plt.plot(xx, func(xx,*popt), ls="--", color="k", 
         label="fit, $beta = ${}".format(popt))
plt.legend()
plt.show()
# Out:
# [0.50761881]

# %% [markdown]
# ### cases

# %%
df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")
cases = np.random.exponential(5, size=100)

# %%
cases
# Out:
# array([1.22492036e+01, 4.31581838e+00, 6.86907872e+00, 6.15622217e+00,
#        2.61381313e+00, 1.72977525e+00, 1.88163344e+00, 2.48283819e+00,
#        4.29996080e+00, 2.54515286e+01, 7.69450736e-01, 4.75538535e+00,
#        1.94526759e+00, 2.62003408e+00, 3.59395990e+00, 5.04919673e-01,
#        5.11774257e+00, 3.74261787e+00, 1.10954088e+00, 5.54028833e+00,
#        8.89156008e+00, 2.97566491e+00, 3.88386319e+00, 2.60803090e+00,
#        1.55441711e+00, 2.23529593e+01, 7.21842146e+00, 1.70600060e+01,
#        4.33624258e+00, 8.50499324e-01, 3.75654960e+00, 2.10283575e+01,
#        2.72259662e+00, 6.83333864e+00, 6.24605296e+00, 1.80051078e+00,
#        8.12945692e+00, 4.14638029e+01, 4.40390453e+00, 1.92818945e+00,
#        5.99394275e-01, 1.04998009e+00, 1.18662182e+00, 3.04370165e+00,
#        4.95740066e+00, 2.36990319e+00, 7.88714626e+00, 5.80221640e-01,
#        1.04031331e+00, 3.86564605e+00, 4.07946790e+00, 3.92695190e+00,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

cases = np.random.exponential(5, size=100)

hist,edges = np.histogram(cases,bins="auto",density=True )

x = edges[:-1]+np.diff(edges)/2.
plt.scatter(x,hist)

func = lambda x,beta: 1./beta*np.exp(-x/beta)

popt, pcov = curve_fit(f=func, xdata=x, ydata=hist) 

print(popt)

xx = np.linspace(0, x.max(), 101)
plt.plot(xx, func(xx,*popt), ls="--", color="k", 
         label="fit, $beta = ${}".format(popt))
plt.legend()
plt.show()
# Out:
# [0.57652871]

# %% [markdown]
# ### deaths

# %%
df = pd.read_csv("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv")
deaths = np.random.exponential(5, size=100)

# %%
deaths
# Out:
# array([ 3.01751277,  4.12187917, 22.93872172,  7.77013245,  7.52414308,
#         4.89817806,  9.32146309,  5.83369515,  0.46134868,  5.94273151,
#         0.81727108,  7.95363943, 11.49123597,  2.30548207,  0.2116566 ,
#         8.23301049,  5.6378398 ,  0.75335018,  4.31906354, 18.76902473,
#         0.17040521,  7.3826311 ,  9.16175067,  4.32578029, 12.06885512,
#         8.13113437,  6.83270549,  4.37898106,  1.14032505,  2.88036972,
#         0.23281691,  0.51413105,  1.9248224 ,  6.65970037,  6.75933618,
#         0.37812973,  3.85906463,  1.31656386,  2.83717271,  9.34216618,
#         4.45983916,  4.62576052,  1.19180597, 11.51232235,  8.1279881 ,
#         0.62857161,  1.81065784,  9.92389868,  0.5094164 ,  0.33204211,
#         4.894069  ,  3.89331368,  2.56798634,  4.0364967 ,  4.83862322,
#         1.9865557 ,  1.31775899,  6.35090836,  0.17879463,  0.49811222,
#         0.90564382,  5.89944833,  7.74227565, 24.27218625, 11.29351521,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

deaths = np.random.exponential(5, size=100)

hist,edges = np.histogram(deaths,bins="auto",density=True )

x = edges[:-1]+np.diff(edges)/2.
plt.scatter(x,hist)

func = lambda x,beta: 1./beta*np.exp(-x/beta)

popt, pcov = curve_fit(f=func, xdata=x, ydata=hist) 

print(popt)

xx = np.linspace(0, x.max(), 101)
plt.plot(xx, func(xx,*popt), ls="--", color="k", 
         label="fit, $beta = ${}".format(popt))
plt.legend()
plt.show()
# Out:
# [0.48712606]

# %% [markdown]
# ### Relationships between variables

# %%
# Using Matplotlib.pyplot plot() function for the .loc () function to investigate relationship between variables:
# cases vs deaths.
plt.plot (df.loc[0:100,"cases"], df.loc[0:100,"deaths"], '.')

# %%
# Using Matplotlib.pyplot plot() function for the .iloc () function to investigate relationship between variables:
# cases vs deaths.
plt.plot (df.iloc[0:100, 4], df.iloc[0:100, 5], '.')

# %%
# Using Matplotlib.pyplot scatter() function for the .loc()function to investigate relationship between variables:
# cases vs deaths.
plt.scatter(df.loc[0:100,"cases"], df.loc[0:100,"deaths"])

# %%
# Using Matplotlib.pyplot scatter() function for the .iloc()function to investigate relationship between variables:
# cases vs deaths.

plt.scatter(df.iloc[0:100,4], df.iloc[0:100,5])

# %%
# Using seaborn regression plot () for the .loc()to investigate relationship between variables:
# cases vs deaths.
sns.regplot(df.loc[0:100,"cases"], df.loc[0:100,"deaths"])

# %%
# Using seaborn regression plot () for the .iloc function to investigate relationship between variables:
# cases vs deaths.
sns.regplot(df.iloc[0:100,4], df.iloc[0:100,5])

# %%
# Using Matplotlib.pyplot plot() function for the .loc () function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
plt.plot (df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"], '.')

# %%
# Using Matplotlib.pyplot plot() function for the .iloc() function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
plt.plot (df.iloc[0:100, 9], df.iloc[0:100, 11], '.')

# %%
# Using Matplotlib.pyplot scatter() function for the .loc()function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
plt.scatter(df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"])

# %%
# Using Matplotlib.pyplot scatter() function for the .iloc()function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
plt.scatter(df.iloc[0:100,9], df.iloc[0:100,11])

# %%
# Using seaborn regression plot () for the .loc() to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
sns.regplot(df.loc[0:100,"popData2019"], df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"])

# %%
# Using seaborn regression plot () for the .iloc function to investigate relationship between variables:
# popData2019 vs Cumulative_number_for_14_days_of_COVID-19_cases_per_100000.
sns.regplot(df.iloc[0:100,9], df.iloc[0:100,11])

# %% [markdown]
# ### Research detail

# %% [markdown]
# #### A real-world phenomenon

# %% [markdown]
# For the purpose of the project on the Programming for Data Analysis 2020, I have chosen the Coronavirus disease 2019
# (COVID-19) pandemic as a real-world phenomenon of interest.

# %% [markdown]
# #### About the dataset

# %% [markdown]
# For the purpose of this project, I use the COVID-19 Data Worldwide dataset.
#
# The COVID-19 Coronavirus data is a dataset containing data on the geographic distribution of COVID-19 cases worldwide [1]. It contains twelve variables including dateRep, day, month, year, cases, deaths, countriesAndTerritories, geold, countryterritoryCode, popData2019, continentExp, and Cumulative_number_for_14_days_of_COVID-19_cases_per_100000. It has 57641(Excel format) entries. The types of variables are as follows seven numerical, four string and one ordinal. Accessing the dataset We had a copy of dataset on our files. The dataset is accessible at the EU Portal webpage [1]. Relevant Python modules Import relevant Python modules to perform multiple operations pertaining to this project: Pandas (data analysis and manipulation), Numpy (numerical operations), Matplotlib.pyplot (plots) and Seaborn (data visualisation). Method of dataset access using Pandas DataFrame () function Use Pandas DataFrame () function as df = pd.read_csv ("COVID-19-geographic-disbtribution-worldwide - Copy - Copy.csv") and call the df () function as df to access the entire dataset.

# %% [markdown]
# #### Summarising the dataset

# %% [markdown]
# Use the following functions DataFrame functions to summarise the dataset: df. head(), df.tail() and df.describe(). The first function outputs columns in number of twelve and five rows starting by index 0 as 1. The second function outputs the last five rows and all twelve columns. The third function outputs the description of the dataset summary including count, mean, std, min, 25%, average (50%), 75% and max.

# %% [markdown]
# #### Selection of four variables of interest and one hundred points

# %% [markdown]
# For the prupose of this project, I have selected the following four variables of interest including cases, deaths, popData2019 and cumulative_number_for_14_days_of_COVID-19_cases_per_100000, and one hundred entries (points). All four variables are numerical. Use df.loc[0:100,["cases","deaths","popData2019", “Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"]]. Use the .iloc() function to display all variables and their values as follows:
# df.iloc[0:100, 4] for the first variable of chosen; df.iloc[0:100, 5] for the second variable of chosen; df.iloc[0:100, 9] for the third variable of chosen and df.iloc[0:100, 11] for the fourth variable of chosen. Investigating variables
#
# Using Matplotlib.pyplot hist() function for the .loc () and .iloc functions to display histograms for each variable. plt.hist(df.loc[0:100,"cases"]) and plt.hist(df.iloc[0:100,"cases"]) for cases, both functions .loc and .iloc produce the same outputs. Histogram is “accurate method for the graphical representation of numerical data distribution” (Geeksforgeeks, 2020) [2]. plt.hist(df.loc[0:100,"deaths"]) and plt.hist(df.iloc[0:100,5]) for deaths. They produce the same results. plt.hist(df.loc[0:100,"popData2019"] and plt.hist(df.iloc[0:100,9]) for the popData2019. They provide identical outputs. plt.hist(df.loc[0:100,"Cumulative_number_for_14_days_of_COVID-19_cases_per_100000"]) and plt.hist(df.iloc[0:100,11]) for Cumulative_number_for_14_days_of_COVID-19_cases_per_100000. They also produce the same results.

# %% [markdown]
# #### Distributions

# %% [markdown]
# #### Relationships

# %% [markdown]
# #### Simulation

# %% [markdown]
# # End

# %% [markdown]
# <br>
